# %% [markdown]
# # Exploratory Data Analysis
#
# Load the transactions dataset, inspect the number of columns, examine category balance, and review transaction descriptions.

# %%
import pandas as pd
import matplotlib.pyplot as plt

train = pd.read_csv('../data/raw/train_transactions.csv')
print(train.head())
train.head()

# %%
train.info()

# %%
train['category'].value_counts()
